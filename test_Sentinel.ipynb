# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import gsw
import cmocean as cmo
#import netcdf64 as nc
#from cookielib import CookieJar
#from urllib import urlencode
 
#import urllib2

# %%
#!/usr/bin/python 
# The user credentials that will be used to authenticate access to the data
 
username = "hdmicord"
password = "Animalsfly27"
  
 
# The url of the file we wish to retrieve
 
url = "https://oceandata.sci.gsfc.nasa.gov/directaccess/MODIS-Aqua/L3BIN/2021/001/A2021001.L3b_DAY_CHL.nc"
 
 
# Create a password manager to deal with the 401 reponse that is returned from
# Earthdata Login
 
password_manager = urllib2.HTTPPasswordMgrWithDefaultRealm()
password_manager.add_password(None, "https://urs.earthdata.nasa.gov", username, password)
 
 
# Create a cookie jar for storing cookies. This is used to store and return
# the session cookie given to use by the data server (otherwise it will just
# keep sending us back to Earthdata Login to authenticate).  Ideally, we
# should use a file based cookie jar to preserve cookies between runs. This
# will make it much more efficient.
 
cookie_jar = CookieJar()
  
 
# Install all the handlers.
 
opener = urllib2.build_opener(
    urllib2.HTTPBasicAuthHandler(password_manager),
    #urllib2.HTTPHandler(debuglevel=1),    # Uncomment these two lines to see
    #urllib2.HTTPSHandler(debuglevel=1),   # details of the requests/responses
    urllib2.HTTPCookieProcessor(cookie_jar))
urllib2.install_opener(opener)
 
 
# Create and submit the request. There are a wide range of exceptions that
# can be thrown here, including HTTPError and URLError. These should be
# caught and handled.
 
request = urllib2.Request(url)
response = urllib2.urlopen(request)
 
 
# Print out the result (not a good idea with binary data!)
 
body = response.read()
print(body)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_55214/3934218579.py in <module>
#      14 # Earthdata Login
#      15
# ---> 16 password_manager = urllib2.HTTPPasswordMgrWithDefaultRealm()
#      17 password_manager.add_password(None, "https://urs.earthdata.nasa.gov", username, password)
#      18
#
# NameError: name 'urllib2' is not defined

# %%
#webbrowser.open(https://coda.eumetsat.int/odata/v1/Products('8ba6d883-86bc-4789-a679-360138600baf')/$value)

# %%
cd /users/
#/Users/username/Documents
# Out:
#   File "/tmp/ipykernel_55214/2206644002.py", line 1
#     cd /users/
#               ^
# SyntaxError: invalid syntax

# %%
data_path = 
#url = 'https://oceandata.sci.gsfc.nasa.gov/directaccess/MODIS-Aqua/L3BIN/2021/001/A2021001.L3b_DAY_CHL.nc'

# %%
#sst_data = xr.open_dataset(url)

# %%
cd MARN5895/Sentinel_project
# Out:
# /home/hmi15101/MARN5895/Sentinel_project

# %%
fn = 'A2021001084500.L2_LAC_OC.nc'

# %%
modis = xr.open_dataset(fn,decode_times=False)

# %%
modis
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     *empty*
# Attributes: (12/50)
#     title:                             MODISA Level-2 Data
#     product_name:                      A2021001084500.L2_LAC_OC.nc
#     processing_version:                2018.1
#     equatorCrossingLongitude:          -97.00057
#     orbit_number:                      99274
#     history:                           l2gen par=/data5/sdpsoper/vdc/vpu16/wo...
#     ...                                ...
#     geospatial_lon_max:                88.81447
#     geospatial_lon_min:                62.286278
#     startDirection:                    Ascending
#     endDirection:                      Ascending
#     day_night_flag:                    Day
#     earth_sun_distance_correction:     1.0342531204223633

# %%
ls
# Out:
# 05_sciencestack.ipynb          RGsal_500_1000_2000.png
# launch_bash_slurm_marn5895.sh  RGsal_surface_vs_deep.png
# MARN5895/                      RGtemp_2004_vs_2018.png
# miniconda/                     RGtemp_500_1000_2000.png
# monthly_sla/                   RGtemp_surface_vs_deep.png
# NOAA_Sealevel_Falmouth.csv     StormSurge_Falmouth.csv
# RG_heat_content.png            Untitled1.ipynb
# RGsal_2004_vs_2018.png         Untitled.ipynb

# %%
data_path = '/Users/Hannah/Downloads/A2021001000500.L2_LAC_OC.nc'

# %%
modis = xr.open_dataset(data_path,decode_times=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda/envs/marn5895/lib/python3.9/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/miniconda/envs/marn5895/lib/python3.9/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/hmi15101/MARN5895/Sentinel project/C:/Users/Hannah/Downloads/A2021001000500.L2_LAC_OC.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# ...
