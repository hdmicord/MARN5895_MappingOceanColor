# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import gsw
import cmocean as cmo

# %%
fn = 'A2021001084500.L2_LAC_OC.nc'

# %%
modis = xr.open_dataset(fn,decode_times=False)
modis
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     *empty*
# Attributes: (12/50)
#     title:                             MODISA Level-2 Data
#     product_name:                      A2021001084500.L2_LAC_OC.nc
#     processing_version:                2018.1
#     equatorCrossingLongitude:          -97.00057
#     orbit_number:                      99274
#     history:                           l2gen par=/data5/sdpsoper/vdc/vpu16/wo...
#     ...                                ...
#     geospatial_lon_max:                88.81447
#     geospatial_lon_min:                62.286278
#     startDirection:                    Ascending
#     endDirection:                      Ascending
#     day_night_flag:                    Day
#     earth_sun_distance_correction:     1.0342531204223633

# %%
fn2 = 'Oa06_radiance.nc'

# %%
sentinel = xr.open_dataset(fn2,decode_times=False)
sentinel
# Out:
# <xarray.Dataset>
# Dimensions:        (rows: 1960, columns: 4865)
# Dimensions without coordinates: rows, columns
# Data variables:
#     Oa06_radiance  (rows, columns) float32 ...
# Attributes: (12/16)
#     absolute_orbit_number:  18320
#     ac_subsampling_factor:  64
#     al_subsampling_factor:  1
#     comment:
#     contact:                ops@eumetsat.int
#     creation_time:          2021-11-01T19:30:13Z
#     ...                     ...
#     references:             S3IPF PDS 004.1 - i2r4 - Product Data Format Spec...
#     resolution:             [ 270 294 ]
#     source:                 IPF-OL-1-EO 06.11
#     start_time:             2021-10-31T13:43:41.753035Z
#     stop_time:              2021-10-31T13:45:07.952772Z
#     title:                  OLCI Level 1b Product, Radiance Oa06 Data Set
